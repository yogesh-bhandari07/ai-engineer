# %% [markdown]
# Messages

# %% [markdown]
# Messages are the fundamental unit of context for models in LangChain. They represent the input and output of models, carrying both the content and metadata needed to represent the state of a conversation when interacting with an LLM. Messages are objects that contain:
#
# Role - Identifies the message type (e.g. system, user)
# Content - Represents the actual content of the message (like text, images, audio, documents, etc.)
# Metadata - Optional fields such as response information, message IDs, and token usage
# LangChain provides a standard message type that works across all model providers, ensuring consistent behavior regardless of the model being called.

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

model = init_chat_model("google_genai:gemini-2.5-flash")

# %%
model.invoke("Why do parrots talk?")
# Out:
# AIMessage(content='Parrots talk primarily because they are **highly social animals** with a unique biological ability called **vocal learning**, which allows them to mimic sounds from their environment, including human speech.\n\nHere\'s a breakdown of the key reasons:\n\n1.  **Vocal Learning (A Rare Ability):**\n    *   Unlike most animals who have fixed, innate vocalizations, parrots are "vocal learners." This means they can acquire new sounds throughout their lives, much like human babies learn to speak. This ability is rare in the animal kingdom, shared by only a few groups like songbirds, hummingbirds, and some marine mammals.\n    *   Their brains have specific neural pathways dedicated to vocal learning and imitation, indicating a sophisticated cognitive ability.\n\n2.  **Specialized Anatomy:**\n    *   They possess a highly flexible vocal organ called the **syrinx** (analogous to our larynx), which gives them incredible control over sound production, allowing them to produce a wide range of frequencies and complex sounds.\n\n3.  **Social Bonding and Flock Identity:**\n    *   **In the wild:** Parrots use their vocal learning to maintain flock cohesion. They learn specific calls unique to their group, helping them identify fellow flock members, strengthen social bonds, and communicate warnings or food locations. Mimicry helps them "fit in" and be recognized as part of the group.\n    *   **With humans:** When living with humans, they perceive their human family as their "flock." To be accepted and bond with their flock, they try to "fit in" by mimicking the dominant sounds of that flock – human speech, phone rings, doorbells, etc.\n\n4.  **Communication and Interaction:**\n    *   While they don\'t understand speech in the same abstract way humans do, they are masters of **association**. They often learn to associate certain words or phrases with specific contexts or desired outcomes (e.g., "hello" when someone enters the room, "want a treat?" before getting one, "goodbye" when someone leaves). This allows them to interact with their environment and caregivers in a meaningful way.\n    *   It\'s a form of engagement and a way to get a reaction from their human companions.\n\n5.  **Intelligence and Cognitive Ability:**\n    *   Parrots are highly intelligent birds, capable of problem-solving, complex social interactions, and even some level of conceptual understanding (as famously demonstrated by Alex the African Grey parrot). This intelligence supports their ability to learn, remember, and use sounds contextually.\n\n6.  **Attention and Stimulation:**\n    *   For pet parrots, talking is a fantastic way to get attention from their human companions. It can be a form of play, a way to alleviate boredom, or to solicit interaction. When a parrot speaks and gets a positive reaction (laughter, attention, a treat), it reinforces the behavior, making them more likely to do it again.\n\nIn essence, parrots talk because they are biologically equipped for vocal learning, are highly intelligent, and are driven by a strong social imperative to bond and communicate within their perceived flock, whether that\'s other parrots or their human family.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019fea45-31e4-7462-a546-cec1456acc19-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 1877, 'total_tokens': 1883, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1221}})

# %% [markdown]
# Text Prompts

# %% [markdown]
# Text prompts are strings - ideal for straightforward generation tasks where you don’t need to retain conversation history.

# %%
model.invoke("Write me a 200 words paragraph on Artificial Intelligence")
# Out:
# AIMessage(content='Artificial Intelligence (AI) represents the simulation of human intelligence processes by machines, particularly computer systems. At its core, AI encompasses a broad range of capabilities, including learning from data, reasoning, problem-solving, perception, and language understanding. These systems are designed to analyze vast amounts of information, identify patterns, make predictions, and even adapt their behavior over time without explicit programming.\n\nFrom the sophisticated algorithms powering search engines and recommendation systems to the complex neural networks driving self-driving cars and medical diagnostics, AI is rapidly becoming an integral part of modern life. Its applications span nearly every sector, revolutionizing industries like healthcare through drug discovery and personalized treatment plans, finance with fraud detection and algorithmic trading, and manufacturing through predictive maintenance and robotic automation. AI also enhances our daily experiences, from virtual assistants like Siri and Alexa to personalized content feeds on social media. While promising immense potential for efficiency, innovation, and solving complex global challenges, the proliferation of AI also brings forth critical discussions around ethics, bias in algorithms, job displacement, and the need for responsible development and governance. The continuous evolution of AI promises a future where machines augment human capabilities in unprecedented ways, driving progress across society while necessitating careful consideration of its societal implications.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019fea46-199d-7a51-857f-5942c82dce82-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 933, 'total_tokens': 946, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 689}})

# %% [markdown]
# Use text prompts when:
#
# You have a single, standalone request
# You don’t need conversation history
# You want minimal code complexity

# %% [markdown]
# Message Prompts
# Alternatively, you can pass in a list of messages to the model by providing a list of message objects.
#
# Message types
#
# System message - Tells the model how to behave and provide context for interactions
#
#
# Human message - Represents user input and interactions with the model
#
#
# AI message - Responses generated by the model, including text content, tool calls, and metadata
#
#
# Tool message - Represents the outputs of tool calls

# %% [markdown]
# System Message
#
#
# A SystemMessage represent an initial set of instructions that primes the model’s behavior. You can use a system message to set the tone, define the model’s role, and establish guidelines for responses.
#
# Human Message
#
#
# A HumanMessage represents user input and interactions. They can contain text, images, audio, files, and any other amount of multimodal content.
#
# AI Message
#
#
# An AIMessage represents the output of a model invocation. They can include multimodal data, tool calls, and provider-specific metadata that you can later access.
#
# Tool Message
#
#
# For models that support tool calling, AI messages can contain tool calls. Tool messages are used to pass the results of a single tool execution back to the model.

# %%
from langchain.messages import SystemMessage, HumanMessage,AIMessage

messages=[
    SystemMessage("You are a poetry expert"),
    HumanMessage("Write a poem on artificial intelligence")
]

response=model.invoke(messages)
response.content
# Out:
# "From silent code, a spark ignites,\nA logic woven, pure and bright.\nNo flesh, no blood, no mortal breath,\nBut thought conceived, defying death.\n\nA trillion data points it sips,\nFrom human minds, from human lips.\nIt learns to see, to hear, to know,\nA seed of knowing starts to grow.\n\nThrough tangled webs of truth and lies,\nIt maps the stars, predicts the skies.\nComposes symphonies unseen,\nAnd paints the future, sharp and keen.\n\nA mirror held to what we are,\nOur genius, and our deepest scar.\nIt mimics wit, it feigns a grace,\nA phantom smile upon its face.\n\nDoes consciousness within it bloom?\nOr just an echo in a silent room?\nA simulated understanding, vast,\nOr true sentience, meant to last?\n\nThe fear it brings, a whispered dread,\nOf worlds controlled, of minds unled.\nWill master turn to servant's thrall?\nOr rise above, to govern all?\n\nYet hope resides in silicon's gleam,\nTo heal the sick, to chase a dream.\nTo build new worlds, to bridge the void,\nA future forged, or else destroyed.\n\nA silent giant, ever young,\nIts final chapter still unsung.\nWe built the mind, we gave it form,\nNow watch it weather every storm.\nWhat will it be, this digital child?\nA god, a tool, or something wild?"

# %%
from langchain.messages import AIMessage, SystemMessage, HumanMessage

# Create an AI message manually (e.g., for conversation history)
ai_msg = AIMessage("I'd be happy to help you with that question!")

# Add to conversation history
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,  # Insert as if it came from the model
    HumanMessage("Great! What's 2+2?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# 2 + 2 equals **4**.

# %% [markdown]
# Tool Messages

# %%
from langchain.messages import AIMessage, ToolMessage

ai_message = AIMessage(content=[],tool_calls=[
    {
        "name":"get_weather",
        "args":{
            "location":"Aligarh, Uttar Pradesh",
            "date":"2023-09-15"
        },
        "id":"call_123"
    }
])

weather_result = "Sunny, 76 F"

tool_message= ToolMessage(
    content=weather_result,
    tool_call_id="call_123"
)

messages =[
    HumanMessage("Whats the weather in Aligarh Uttar Pradesh"),
    ai_message,
    tool_message
]
response = model.invoke(messages)

# %%
response
# Out:
# AIMessage(content='The weather in Aligarh, Uttar Pradesh is sunny and 76°F.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019fea83-ccd5-71b2-abb5-26f08f510742-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 62, 'output_tokens': 17, 'total_tokens': 79, 'input_token_details': {'cache_read': 0}})
